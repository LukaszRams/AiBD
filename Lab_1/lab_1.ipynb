# %% [markdown]
# ## Laboratorium 1
# **Łukasz Rams**
#
# 1.10.2021r
#
# piątek 9:15

# %% [markdown]
# **Import modułów**

# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ### Zadanie 3
#
# W tym ćwiczeniu należało zdefiniować funkcję:
#
# $ f(x)=x^2+5 $
#
# oraz narysować jej wykres dla argumentów:
#
# a) $ x>-1 $ oraz $ x<1 $
#
# b) $ x>-6 $ oraz $ x<6 $
#
# c) $ x>0 $ oraz $ x<5 $

# %%
# zdefiniowanie funkcji
def fun(x):
    return x**2+5

# zdefiniowanie argumentów (biorę od drugiego elementu, gdyż jest nierówność nieostra)
x_1 = np.arange(-1, 1, 0.01)[1:]
x_2 = np.arange(-6, 6, 0.01)[1:]
x_3 = np.arange(-0, 5, 0.01)[1:]


# rysowanie wykresu dla pierwszych argumentów
fig = plt.figure()
axs = plt.subplot()
axs.plot(x_1, fun(x_1), label="y=x**2+5")
axs.legend()
axs.set_title("Przebieg funkcji dla argumentów (-1, 1)")
axs.set_xlabel("x")
axs.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
# rysowanie wykresu dla drugich argumentów
fig = plt.figure()
axs = plt.subplot()
axs.plot(x_2, fun(x_2), label="y=x**2+5")
axs.legend()
axs.set_title("Przebieg funkcji dla argumentów (-6, 6)")
axs.set_xlabel("x")
axs.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
# rysowanie wykresu dla ostatnich argumentów
fig = plt.figure()
axs = plt.subplot()
axs.plot(x_3, fun(x_3), label="y=x**2+5")
axs.legend()
axs.set_title("Przebieg funkcji dla argumentów (0, 5)")
axs.set_xlabel("x")
axs.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Zadanie 4
#
# W zadaniu tym należało utworzyć ***dataframe***, a następnie dodać do nigo pięć rekordów i wyświetlić informację o danych, opis danych oraz trzy pierwsze wiersze.
#
# ***Dataframe*** miał zawierać kolumny:
#
# - name
#
# - surname
#
# - age
#
# - sex

# %%
# import biblioteki pandas
import pandas as pd

# %% [markdown]
# **Stworzenie danych i utworzenie dataframe**

# %%
# zdefiniowanie danych
data = {"name": ["Łukasz", "Arkadiusz", "Piotr", "Daniel", "Paweł"],
       "surname": ["Kot", "Olech", "Ul", "Król", "Wilk"],
       "age": [16, 19, 20, 56, 74],
       "sex": ["men", "men", "men", "men", "men"]}

# utworzenie dataframe
df = pd.DataFrame(data)

# %% [markdown]
# **Wyświetlenie informacji o danych**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     5 non-null      object
#  1   surname  5 non-null      object
#  2   age      5 non-null      int64
#  3   sex      5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 288.0+ bytes

# %% [markdown]
# **Opis danych**

# %%
df.describe()
# Out:
#              age
# count   5.000000
# mean   37.000000
# std    26.381812
# min    16.000000
# 25%    19.000000
# 50%    20.000000
# 75%    56.000000
# max    74.000000

# %% [markdown]
# **Trzy pierwsze rekordy**

# %%
df.head(3)
# Out:
#         name surname  age  sex
# 0     Łukasz     Kot   16  men
# 1  Arkadiusz   Olech   19  men
# 2      Piotr      Ul   20  men
